# %% [markdown]
# Welcome to the history lesson of one of the most popular programming languages, Python. Let's start by imagining that programming languages are like different languages spoken around the world. Just like how we have English, French, Spanish, Chinese, and many more, there are different programming languages, each with its own unique characteristics and uses.
#
# Python, in this context, is like a language that is easy to learn and understand. It's like learning a language that uses simple grammar and has a straightforward structure. Just like how you can express your thoughts and ideas more easily if you know a language that is easy to use, programming in Python is easier because of its simplicity.
#
# Python was created in the late 1980s by a Dutch programmer named Guido van Rossum. He wanted to create a language that was easy to read and write, and that's how Python was born. Python was named after a British comedy group, Monty Python.
#
# Over the years, Python has evolved and grown in popularity. It's used in a wide range of applications, from web development to data science and artificial intelligence. Just like how a language can help you communicate your ideas to others, Python helps programmers communicate their instructions to computers.
#
# In conclusion, Python is like a language that is simple to learn, easy to use, and has a wide range of applications. It's no wonder that it has become one of the most popular programming languages in the world.

# %% [markdown]
# # Python History
#
# Welcome to the first class of Introduction to Computer Science! Today, we are going to discuss the history of Python programming language.
#
# Python was created by Guido van Rossum in the late 1980s and was first released in 1991. The language was named after Monty Python, a British comedy group, and not the reptile, as some people may think.
#
# ## Why Python?
#
# Python is a high-level programming language that is easy to learn and use. It has a simple syntax, which means that the code is easy to read and write. It is also a versatile language that can be used for a wide range of applications, including web development, data analysis, artificial intelligence, and more.
#
# ## Example
#
# To understand the history of Python, let's look at a simple example.
#
# ```python
# # This is a comment in Python
# # This program prints "Hello, World!"
#
# print("Hello, World!")
# ```
#
# In this example, we are using Python to print the message "Hello, World!" to the screen. The `print()` function is a built-in function in Python that allows us to display text on the screen.
#
# This program may seem simple, but it is an essential part of the history of programming languages. The "Hello, World!" program has been used as a test program for many programming languages since the 1970s. It is an easy way to test if the language is installed correctly, and it is a good way to introduce beginners to programming.
#
# ## Conclusion
#
# In conclusion, Python is a powerful programming language that has a rich history. It was created by Guido van Rossum in the late 1980s and was first released in 1991. Python's simplicity and versatility have made it one of the most popular programming languages in the world.

# %% [markdown]
# Problem:
#
# Write a Python program that takes a list of Python versions and their release dates as input and sorts them based on the year they were released.
#
# Input:
# The first line of input contains an integer N, representing the number of Python versions in the list. The next N lines contain the Python version number (e.g., "Python 1.0") and the release date in the format "DD-MMM-YYYY" (e.g., "20-Feb-1991").
#
# Output:
# Print the sorted list of Python versions in ascending order of the year they were released. Each line should contain the version number and the release date in the format "Python version_number - release_date".
#
# Example:
#
# Input:
# 5
# Python 0.9.0 - 20-Jan-1991
# Python 0.9.1 - 10-Feb-1991
# Python 1.0 - 20-Feb-1991
# Python 1.5 - 31-Dec-1997
# Python 2.0 - 16-Oct-2000
#
# Output:
# Python 0.9.0 - 20-Jan-1991
# Python 0.9.1 - 10-Feb-1991
# Python 1.0 - 20-Feb-1991
# Python 1.5 - 31-Dec-1997
# Python 2.0 - 16-Oct-2000
#
# Explanation:
# The input contains 5 Python versions, with release dates ranging from 1991 to 2000. The output is sorted in ascending order of the year they were released.

# %%
Sure, I'd be happy to help! Here's an example of some code with empty methods and comments to explain what they should do:

```python
class MyClass:
    def __init__(self):
        self.my_list = []

    def add_to_list(self, item):
        # This method should add the given item to my_list
        pass

    def remove_from_list(self, item):
        # This method should remove the given item from my_list
        pass

    def get_list_length(self):
        # This method should return the length of my_list
        pass
```

And here are three assertion tests that a student could use to check if they've implemented these methods correctly:

```python
def test_my_class():
    test_class = MyClass()
    test_class.add_to_list('apple')
    test_class.add_to_list('banana')
    test_class.add_to_list('cherry')
    assert test_class.get_list_length() == 3

    test_class.remove_from_list('banana')
    assert test_class.get_list_length() == 2

    test_class.remove_from_list('apple')
    test_class.remove_from_list('cherry')
    assert test_class.get_list_length() == 0
```

These tests should check that the `add_to_list`, `remove_from_list`, and `get_list_length` methods are working as expected. The first test adds three items to the list and checks that the length is 3. The second test removes an item and checks that the length is now 2. The third test removes the remaining items and checks that the length is 0.
